# %%
print("Die Zielvariable für die Vorhersage ist der Fahrpreis (fare_amount), ")
print("der in US-Dollar angegeben ist. Das Modell wird trainiert, um den Fahrpreis ")
print("basierend auf den Eingabedaten wie der Fahrtdistanz, der Anzahl der Fahrgäste ")
print("und anderen relevanten Attributen vorherzusagen.")
# Out:
# Die Zielvariable für die Vorhersage ist der Fahrpreis (fare_amount),
# der in US-Dollar angegeben ist. Das Modell wird trainiert, um den Fahrpreis
# basierend auf den Eingabedaten wie der Fahrtdistanz, der Anzahl der Fahrgäste
# und anderen relevanten Attributen vorherzusagen.

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt  # Make sure this line is present
from sklearn.preprocessing import MinMaxScaler

file_path = r"C:\Users\eloik\.jupyter\nyc_taxi_fare_cleaned.csv"
df = pd.read_csv(file_path)

# %%
stats = df.describe().T
print(stats)

plt.figure(figsize=(10, 6))
plt.hist(df["fare_amount"], bins=100, edgecolor="black", alpha=0.7, log=True)
plt.xlabel("Fare Amount (USD)")
plt.ylabel("Frequency (log scale)")
plt.title("Histogram of Taxi Fare Amounts")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
# Out:
#                         count       mean       std          min        25%  \
# fare_amount        54315955.0  11.324251  9.686620     0.010000   6.000000
# pickup_longitude   54315955.0 -73.974866  7.539223 -3492.263768 -73.992282
# pickup_latitude    54315955.0  40.751316  6.900053 -3458.664702  40.736552
# dropoff_longitude  54315620.0 -73.985354  7.580804 -3493.651853 -73.991588
# dropoff_latitude   54315620.0  40.762279  6.827856 -3309.274703  40.735559
# passenger_count    54315955.0   1.685482  1.308879     0.000000   1.000000
#
#                          50%        75%          max
# fare_amount         8.500000  12.500000   500.000000
# pickup_longitude  -73.982093 -73.968290  3439.425565
# pickup_latitude    40.753370  40.767555  3457.625683
# dropoff_longitude -73.980600 -73.965332  3211.579750
# dropoff_latitude   40.753854  40.768397  3537.132528
# passenger_count     1.000000   2.000000     8.000000

# %%
from sklearn.preprocessing import StandardScaler

# Skalierung des Fahrpreises
scaler = StandardScaler()
df['fare_amount_scaled'] = scaler.fit_transform(df[['fare_amount']])

# Anzeigen der skalierten Daten
print(df[['fare_amount', 'fare_amount_scaled']].head())

# Argumentation, warum Skalierung sinnvoll ist
argumentation = """
Skalierung ist in diesem Fall sinnvoll, da die Fahrpreise eine breite Spanne aufweisen können.
Durch die Skalierung werden die Daten auf eine gemeinsame Skala gebracht, was die Leistung
von maschinellen Lernmodellen verbessern kann, insbesondere wenn Algorithmen verwendet werden,
die auf euklidischen Abständen basieren, wie z.B. k-Nearest Neighbors oder Support Vector Machines.
"""
print(argumentation)
# Out:
#    fare_amount  fare_amount_scaled
# 0          4.5           -0.704503
# 1         16.9            0.575614
# 2          5.7           -0.580621
# 3          7.7           -0.374150
# 4          5.3           -0.621915
#
# Skalierung ist in diesem Fall sinnvoll, da die Fahrpreise eine breite Spanne aufweisen können.
# Durch die Skalierung werden die Daten auf eine gemeinsame Skala gebracht, was die Leistung
# von maschinellen Lernmodellen verbessern kann, insbesondere wenn Algorithmen verwendet werden,
# die auf euklidischen Abständen basieren, wie z.B. k-Nearest Neighbors oder Support Vector Machines.
